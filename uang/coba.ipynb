# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#       R   G   B  label
# 0    27  32  23     10
# 1    28  32  24     10
# 2    27  31  23     10
# 3    28  31  23     10
# 4    28  33  24     10
# ..   ..  ..  ..    ...
# 118  21  23  21      2
# 119  26  29  27      2
# 120  25  28  26      2
# 121  32  37  34      2
# 122  21  23  20      2
#
# [123 rows x 4 columns]

# %%
df.label.unique()
# Out:
# array([ 10,   5, 100,  50,   1,   2], dtype=int64)

# %%
df = pd.get_dummies(df, columns=['label'])
df
# Out:
#       R   G   B  label_1  label_2  label_5  label_10  label_50  label_100
# 0    27  32  23        0        0        0         1         0          0
# 1    28  32  24        0        0        0         1         0          0
# 2    27  31  23        0        0        0         1         0          0
# 3    28  31  23        0        0        0         1         0          0
# 4    28  33  24        0        0        0         1         0          0
# ..   ..  ..  ..      ...      ...      ...       ...       ...        ...
# 118  21  23  21        0        1        0         0         0          0
# 119  26  29  27        0        1        0         0         0          0
# 120  25  28  26        0        1        0         0         0          0
# 121  32  37  34        0        1        0         0         0          0
# 122  21  23  20        0        1        0         0         0          0
#
# [123 rows x 9 columns]

# %%
df["label_1"] = 0
df["label_2"] = 1
df["label_5"] = 2
df["label_10"] = 3
df["label_50"] = 4
df["label_100"] = 5

# %%
df.shape
# Out:
# (123, 9)

# %%
df = df.sample(frac=1)
df.head()
# Out:
#      R   G   B  label_1  label_2  label_5  label_10  label_50  label_100
# 29  28  33  23        0        1        2         3         4          5
# 67  37  29  20        0        1        2         3         4          5
# 2   27  31  23        0        1        2         3         4          5
# 45  22  25  23        0        1        2         3         4          5
# 18  22  26  20        0        1        2         3         4          5
