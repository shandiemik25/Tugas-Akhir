# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %%
df = pd.read_csv('dataset.csv')
df
# Out:
#       R   G   B  label
# 0    27  32  23     10
# 1    28  32  24     10
# 2    27  31  23     10
# 3    28  31  23     10
# 4    28  33  24     10
# ..   ..  ..  ..    ...
# 118  21  23  21      2
# 119  26  29  27      2
# 120  25  28  26      2
# 121  32  37  34      2
# 122  21  23  20      2
#
# [123 rows x 4 columns]

# %%
df.dtypes
# Out:
# R            int64
# G            int64
# B            int64
# label_1      uint8
# label_2      uint8
# label_5      uint8
# label_10     uint8
# label_50     uint8
# label_100    uint8
# dtype: object

# %%
df.label.unique()
# Out:
# array([ 10,   5, 100,  50,   1,   2], dtype=int64)

# %%
df = pd.get_dummies(df, columns=['label'])
df
# Out:
#       R   G   B  label_1  label_2  label_5  label_10  label_50  label_100
# 0    27  32  23        0        0        0         1         0          0
# 1    28  32  24        0        0        0         1         0          0
# 2    27  31  23        0        0        0         1         0          0
# 3    28  31  23        0        0        0         1         0          0
# 4    28  33  24        0        0        0         1         0          0
# ..   ..  ..  ..      ...      ...      ...       ...       ...        ...
# 118  21  23  21        0        1        0         0         0          0
# 119  26  29  27        0        1        0         0         0          0
# 120  25  28  26        0        1        0         0         0          0
# 121  32  37  34        0        1        0         0         0          0
# 122  21  23  20        0        1        0         0         0          0
#
# [123 rows x 9 columns]

# %%
df = df.sample(frac=1)
df.head()
# Out:
#       R   G   B  label_1  label_2  label_5  label_10  label_50  label_100
# 59   21  28  22        0        0        0         0         0          1
# 118  21  23  21        0        1        0         0         0          0
# 25   27  33  23        0        0        0         1         0          0
# 87   28  29  23        1        0        0         0         0          0
# 86   27  28  25        1        0        0         0         0          0

# %%
x = df[["R", "G", "B"]]
y = df[["label_1", "label_2", "label_5", "label_10", "label_50", "label_100"]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\SHANDIE\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# c:\Users\SHANDIE\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# c:\Users\SHANDIE\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'label'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18324/1802115180.py in <module>
#       1 x = df[["R", "G", "B"]]
# ----> 2 y = df['label']
#
# c:\Users\SHANDIE\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# c:\Users\SHANDIE\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'label'
